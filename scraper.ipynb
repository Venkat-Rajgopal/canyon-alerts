# %%
from bs4 import BeautifulSoup
import requests
import re
import pickle
import os.path

url = 'https://www.canyon.com/en-de/road-bikes/endurance-bikes/endurace/cf-sl/endurace-cf-sl-7-disc/2947.html?dwvar_2947_pv_rahmenfarbe=YE%2FBK'

#soup = BeautifulSoup(url)

req = requests.get(url=url)
dump = req.content
soup1 = BeautifulSoup(dump, 'html.parser')
print(soup1)

curlist = soup1.find_all('script')[2]
curlist
# Out:
# <!DOCTYPE html>
# <html lang="en-de">
# <head>
# <meta charset="utf-8"/>
# <meta content="ie=edge" http-equiv="x-ua-compatible"/>
# <meta content="width=device-width, initial-scale=1, minimum-scale=1, maximum-scale=5, user-scalable=yes" name="viewport"/>
# <script>
# (function() {
#   var d = document;
#   var c = d.createElement('script');
#   if (!('noModule' in c) && 'onbeforeload' in c) {
#     var s = false;
#     d.addEventListener('beforeload', function(e) {
#       if (e.target === c) {
#         s = true;
#       } else if (!e.target.hasAttribute('nomodule') || !s) {
#         return;
#       }
#       e.preventDefault();
#     }, true);
#
#     c.type = 'module';
#     c.src = '.';
#     d.head.appendChild(c);
#     c.remove();
#   }
# }());
# </script>
# <script>
#   (function() {
#     if (!window.HTMLPictureElement) {
#       document.createElement('picture');
#       var s = document.createElement('script');
# ...

# %%
type(soup1)
# Out:
# bs4.BeautifulSoup

# %%
type(curlist)
# Out:
# bs4.element.Tag

# %%
# curlist = soup1.find_all('script')[2]
soup1.find_all('span', class_ = 'productConfiguration__shippingDateEnd')

# soup1.span.clear()
# print(lst.get_text().strip())
# Out:
# [<span class="productConfiguration__shippingDateEnd">Jul 30, 2021</span>,
#  <span class="productConfiguration__shippingDateEnd">Jul 30, 2021</span>]

# %%
import requests, re, json

r = requests.get('https://www.canyon.com/en-de/road-bikes/endurance-bikes/endurace/cf-sl/endurace-cf-sl-7-disc/2947.html?dwvar_2947_pv_rahmenfarbe=YE%2FBK')
s = re.search(r'window\.deptsfra=(.*);', r.text).group(1)
#print(s)
data = json.loads(s)

# %%
from pprint import pprint
#pprint(data['productDetail']['variationAttributes'][1]['values'])

for i in data['productDetail']['variationAttributes'][1]['values']:
    print(i['availability'])
    break
# Out:
# {'messages': ['Back order'], 'inStockDate': '2021-08-09T00:00:00.000Z', 'onlyXLeftNumber': 1, 'onlyXLeft': False, 'lowStock': False, 'shippingInfo': 'Coming in August 2021', 'available': False, 'availableSufficient': True, 'notifyMe': True, 'showOutOfStock': False, 'similarBikes': False, 'comingSoonByBackOrderAllocation': False}

# %%
pprint(data['productDetail']['variationAttributes'][1]['values'][6])
# Out:
# {'availability': {'available': True,
#                   'availableSufficient': True,
#                   'comingSoonByBackOrderAllocation': False,
#                   'inStockDate': '2021-07-26T00:00:00.000Z',
#                   'lowStock': False,
#                   'messages': ['Back order'],
#                   'notifyMe': False,
#                   'onlyXLeft': False,
#                   'onlyXLeftNumber': 10,
#                   'shippingInfo': 'Shipping <span '
#                                   'class="productConfiguration__shippingDate">Jul '
#                                   '26, 2021</span><span '
#                                   'class="productConfiguration__shippingDateSeparator"> '
#                                   '- </span><span '
#                                   'class="productConfiguration__shippingDateEnd">Jul '
#                                   '30, 2021</span>',
#                   'showOutOfStock': False,
# ...
